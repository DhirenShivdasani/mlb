# %%
import pandas as pd

# Load the CSV files
betting_odds_data = pd.read_csv('mlb_props.csv')
prizepicks_data = pd.read_csv('test2.csv')

# Display the data to understand its structure
betting_odds_data[betting_odds_data['team'] == 'BAL']
# Out:
#              PlayerName team   opp        Prop Over_Under  draftkings  \
# 18      Adley Rutschman  BAL  @CWS       bases       Over   (1.5) 105
# 19      Adley Rutschman  BAL  @CWS       bases      Under  (1.5) -135
# 20      Adley Rutschman  BAL  @CWS        runs       Over  (0.5) -105
# 21      Adley Rutschman  BAL  @CWS        runs      Under  (0.5) -125
# 86    Anthony Santander  BAL  @CWS       bases       Over   (1.5) 120
# 87    Anthony Santander  BAL  @CWS       bases      Under  (1.5) -155
# 88    Anthony Santander  BAL  @CWS        runs       Over   (0.5) 100
# 89    Anthony Santander  BAL  @CWS        runs      Under  (0.5) -130
# 98          Austin Hays  BAL  @CWS       bases       Over   (1.5) 145
# 99          Austin Hays  BAL  @CWS       bases      Under  (1.5) -195
# 100         Austin Hays  BAL  @CWS        runs       Over   (0.5) 130
# 101         Austin Hays  BAL  @CWS        runs      Under  (0.5) -175
# 230      Cedric Mullins  BAL  @CWS       bases       Over      (0.5)
# 231      Cedric Mullins  BAL  @CWS       bases      Under      (0.5)
# 232      Cedric Mullins  BAL  @CWS        runs       Over      (0.5)
# 233      Cedric Mullins  BAL  @CWS        runs      Under      (0.5)
# 266       Colton Cowser  BAL  @CWS       bases       Over  (0.5) -120
# 267       Colton Cowser  BAL  @CWS       bases      Under  (0.5) -110
# 268       Colton Cowser  BAL  @CWS        runs       Over   (0.5) 155
# 269       Colton Cowser  BAL  @CWS        runs      Under  (0.5) -210
# 456    Gunnar Henderson  BAL  @CWS       bases       Over  (0.5) -180
# 457    Gunnar Henderson  BAL  @CWS       bases      Under   (0.5) 135
# 458    Gunnar Henderson  BAL  @CWS        runs       Over   (0.5) 100
# 459    Gunnar Henderson  BAL  @CWS        runs      Under  (0.5) -135
# 564        James McCann  BAL  @CWS       bases       Over  (0.5) -170
# 565        James McCann  BAL  @CWS       bases      Under   (0.5) 125
# 566        James McCann  BAL  @CWS        runs       Over   (0.5) 165
# 567        James McCann  BAL  @CWS        runs      Under  (0.5) -225
# 664     Jordan Westburg  BAL  @CWS       bases       Over   (1.5) 120
# 665     Jordan Westburg  BAL  @CWS       bases      Under  (1.5) -160
# 666     Jordan Westburg  BAL  @CWS        runs       Over   (0.5) 100
# 667     Jordan Westburg  BAL  @CWS        runs      Under  (0.5) -135
# 668         Jorge Mateo  BAL  @CWS       bases       Over   (1.5) 145
# 669         Jorge Mateo  BAL  @CWS       bases      Under  (1.5) -195
# 670         Jorge Mateo  BAL  @CWS        runs       Over   (0.5) 125
# 671         Jorge Mateo  BAL  @CWS        runs      Under  (0.5) -165
# 752        Kyle Bradish  BAL  @CWS  strikeouts       Over   (5.5) 100
# 753        Kyle Bradish  BAL  @CWS  strikeouts      Under  (5.5) -125
# 1070   Ryan Mountcastle  BAL  @CWS       bases       Over   (1.5) 100
# 1071   Ryan Mountcastle  BAL  @CWS       bases      Under  (1.5) -135
# 1072   Ryan Mountcastle  BAL  @CWS        runs       Over   (0.5) 105
# 1073   Ryan Mountcastle  BAL  @CWS        runs      Under  (0.5) -140
#
#          fanduel         mgm
# 18           NaN   (1.5) 110
# 19           NaN  (1.5) -140
# 20           NaN  (0.5) -105
# 21           NaN  (0.5) -125
# 86           NaN   (1.5) 120
# 87           NaN  (1.5) -155
# 88           NaN   (0.5) 100
# 89           NaN  (0.5) -130
# 98           NaN   (1.5) 145
# 99           NaN  (1.5) -190
# 100          NaN   (0.5) 130
# 101          NaN  (0.5) -175
# 230          NaN      (0.5)
# 231          NaN      (0.5)
# 232          NaN      (0.5)
# 233          NaN      (0.5)
# 266          NaN  (0.5) -120
# 267          NaN  (0.5) -105
# 268          NaN   (0.5) 155
# 269          NaN  (0.5) -200
# 456          NaN  (0.5) -175
# 457          NaN   (0.5) 130
# 458          NaN   (0.5) 105
# 459          NaN  (0.5) -135
# 564          NaN  (0.5) -165
# 565          NaN   (0.5) 125
# 566          NaN   (0.5) 165
# 567          NaN  (0.5) -225
# 664          NaN   (1.5) 125
# 665          NaN  (1.5) -160
# 666          NaN   (0.5) 100
# 667          NaN  (0.5) -135
# 668          NaN   (1.5) 145
# 669          NaN  (1.5) -190
# 670          NaN   (0.5) 125
# 671          NaN  (0.5) -160
# 752    (5.5) 100  (5.5) -110
# 753   (5.5) -128  (5.5) -120
# 1070         NaN   (1.5) 100
# 1071         NaN  (1.5) -130
# 1072         NaN   (0.5) 105
# 1073         NaN  (0.5) -135

# %%
prizepicks_data['Prop'].unique()
# Out:
# array(['Hitter Fantasy Score', 'Pitcher Strikeouts', 'Total Bases',
#        '1st Inning Runs Allowed', 'Pitcher Fantasy Score', 'Runs',
#        'Pitcher Strikeouts (Combo)', 'Hits Allowed', 'Walks Allowed',
#        'Hits+Runs+RBIs', 'Singles', 'Pitching Outs', 'Walks', 'Hits',
#        'Earned Runs Allowed', 'Hitter Strikeouts'], dtype=object)

# %%
prizepicks_data = prizepicks_data[(prizepicks_data['Prop'] == 'Total Bases') | 
                                  (prizepicks_data['Prop'] == 'Pitcher Strikeouts') | 
                                  (prizepicks_data['Prop'] == 'Earned Runs Allowed')]

# %%
prizepicks_data
# Out:
#      Unnamed: 0           Name     Team  Value                 Prop
# 1             1   Martín Pérez  PIT - P    3.5   Pitcher Strikeouts
# 2             2  Ranger Suárez  PHI - P    5.5   Pitcher Strikeouts
# 3             3     Chris Sale  ATL - P    7.5   Pitcher Strikeouts
# 5             5      Joey Bart  PIT - C    0.5          Total Bases
# 8             8    Taj Bradley   TB - P    5.5   Pitcher Strikeouts
# ..          ...            ...      ...    ...                  ...
# 223         223   Tanner Houck  BOS - P    2.5  Earned Runs Allowed
# 224         224  Michael Wacha   KC - P    2.5  Earned Runs Allowed
# 225         225    Sean Manaea  NYM - P    2.5  Earned Runs Allowed
# 226         226  Cal Quantrill  COL - P    3.5  Earned Runs Allowed
# 227         227     Ben Lively  CLE - P    2.5  Earned Runs Allowed
#
# [64 rows x 5 columns]

# %%
prop_types= {
    'Pitcher Strikeouts': 'Strikeouts',
    'Earned Runs Allowed': 'Runs',
    'Total Bases': 'Total Bases'# example of making an indirect relationship
    # Add other mappings as required
}
prizepicks_data['Prop'] = prizepicks_data['Prop'].map(prop_types)

# %%
prizepicks_data
# Out:
#      Unnamed: 0           Name     Team  Value         Prop
# 1             1   Martín Pérez  PIT - P    3.5   Strikeouts
# 2             2  Ranger Suárez  PHI - P    5.5   Strikeouts
# 3             3     Chris Sale  ATL - P    7.5   Strikeouts
# 5             5      Joey Bart  PIT - C    0.5  Total Bases
# 8             8    Taj Bradley   TB - P    5.5   Strikeouts
# ..          ...            ...      ...    ...          ...
# 223         223   Tanner Houck  BOS - P    2.5         Runs
# 224         224  Michael Wacha   KC - P    2.5         Runs
# 225         225    Sean Manaea  NYM - P    2.5         Runs
# 226         226  Cal Quantrill  COL - P    3.5         Runs
# 227         227     Ben Lively  CLE - P    2.5         Runs
#
# [64 rows x 5 columns]

# %%
prop_types= {
    'strikeouts': 'Strikeouts',
    'runs': 'Runs', 
    'bases': 'Total Bases'# example of making an indirect relationship
    # Add other mappings as required
}
betting_odds_data['Prop'] = betting_odds_data['Prop'].map(prop_types)

# %%
betting_odds_data['Prop'].unique()
# Out:
# array(['Strikeouts', 'Total Bases', 'Runs'], dtype=object)

# %%
prizepicks_data['Prop'].unique()
# Out:
# array(['Strikeouts', 'Total Bases', 'Runs'], dtype=object)

# %%
# Merging the datasets on player names and props
merged_data = pd.merge(betting_odds_data, prizepicks_data, left_on=['PlayerName', 'Prop'], right_on=['Name', 'Prop'], how='left')

# import ace_tools as tools; tools.display_dataframe_to_user(name="Merged Betting Data", dataframe=merged_data)

# Display the first few rows of the merged data
merged_data
# Out:
#         PlayerName team   opp         Prop Over_Under  draftkings     fanduel  \
# 0     Aaron Brooks  OAK   HOU   Strikeouts       Over   (3.5) 110   (3.5) 130
# 1     Aaron Brooks  OAK   HOU   Strikeouts      Under  (3.5) -140  (3.5) -166
# 2      Aaron Judge  NYY   @SD  Total Bases       Over  (1.5) -105         NaN
# 3      Aaron Judge  NYY   @SD  Total Bases      Under  (1.5) -125         NaN
# 4      Aaron Judge  NYY   @SD         Runs       Over  (0.5) -130         NaN
# ...            ...  ...   ...          ...        ...         ...         ...
# 1267    Zack Gelof  OAK   HOU         Runs      Under  (0.5) -265         NaN
# 1268    Zack Short  ATL  @PIT  Total Bases       Over  (0.5) -120         NaN
# 1269    Zack Short  ATL  @PIT  Total Bases      Under  (0.5) -110         NaN
# 1270    Zack Short  ATL  @PIT         Runs       Over   (0.5) 145         NaN
# 1271    Zack Short  ATL  @PIT         Runs      Under  (0.5) -195         NaN
#
#              mgm  Unnamed: 0          Name      Team  Value
# 0      (3.5) 110        34.0  Aaron Brooks   OAK - P    3.0
# 1     (3.5) -140        34.0  Aaron Brooks   OAK - P    3.0
# 2     (1.5) -105         NaN           NaN       NaN    NaN
# 3     (1.5) -125         NaN           NaN       NaN    NaN
# 4     (0.5) -135         NaN           NaN       NaN    NaN
# ...          ...         ...           ...       ...    ...
# 1267  (0.5) -250         NaN           NaN       NaN    NaN
# 1268  (0.5) -120        44.0    Zack Short  ATL - IF    0.5
# 1269  (0.5) -110        44.0    Zack Short  ATL - IF    0.5
# 1270   (0.5) 145         NaN           NaN       NaN    NaN
# 1271  (0.5) -190         NaN           NaN       NaN    NaN
#
# [1272 rows x 12 columns]

# %%
r = merged_data.drop(['Team', 'Name', 'Unnamed: 0'], axis =1)

# %%
r =r.dropna(subset=['Value'])

# %%
r = r.where(pd.notnull(r), "None")

# %%
r.to_csv('merged_data.csv')

# %%
df = pd.read_csv('merged_data.csv')

# %%
df
# Out:
#     Unnamed: 0          PlayerName team   opp        Prop Over_Under  \
# 0            0        Aaron Civale   TB    KC  Strikeouts       Over
# 1            1        Aaron Civale   TB    KC  Strikeouts      Under
# 2            6          Aaron Nola  PHI  @COL  Strikeouts       Over
# 3            7          Aaron Nola  PHI  @COL  Strikeouts      Under
# 4          106        Brady Singer   KC   @TB  Strikeouts       Over
# 5          107        Brady Singer   KC   @TB  Strikeouts       Over
# 6          108        Brady Singer   KC   @TB  Strikeouts      Under
# 7          109        Brady Singer   KC   @TB  Strikeouts      Under
# 8          274       Dakota Hudson  COL   PHI  Strikeouts       Over
# 9          275       Dakota Hudson  COL   PHI  Strikeouts      Under
# 10         324         Dylan Cease   SD   NYY  Strikeouts       Over
# 11         325         Dylan Cease   SD   NYY  Strikeouts      Under
# 12         362         Erick Fedde  CWS   BAL  Strikeouts       Over
# 13         363         Erick Fedde  CWS   BAL  Strikeouts      Under
# 14         448       Hunter Greene  CIN   LAD  Strikeouts       Over
# 15         449       Hunter Greene  CIN   LAD  Strikeouts      Under
# 16         490            JP Sears  OAK   HOU  Strikeouts       Over
# 17         491            JP Sears  OAK   HOU  Strikeouts      Under
# 18         536     Jameson Taillon  CHC  @STL  Strikeouts       Over
# 19         537     Jameson Taillon  CHC  @STL  Strikeouts      Under
# 20         640        Jordan Hicks   SF  @NYM  Strikeouts       Over
# 21         641        Jordan Hicks   SF  @NYM  Strikeouts       Over
# 22         642        Jordan Hicks   SF  @NYM  Strikeouts      Under
# 23         643        Jordan Hicks   SF  @NYM  Strikeouts      Under
# 24         644   Jordan Montgomery  ARI   MIA  Strikeouts       Over
# 25         645   Jordan Montgomery  ARI   MIA  Strikeouts      Under
# 26         786       Logan Gilbert  SEA  @WSH  Strikeouts       Over
# 27         787       Logan Gilbert  SEA  @WSH  Strikeouts      Under
# 28         816       Luis Severino  NYM    SF  Strikeouts       Over
# 29         817       Luis Severino  NYM    SF  Strikeouts      Under
# 30         846      Marcus Stroman  NYY   @SD  Strikeouts       Over
# 31         847      Marcus Stroman  NYY   @SD  Strikeouts      Under
# 32         888    Michael Lorenzen  TEX  @MIN  Strikeouts       Over
# 33         889    Michael Lorenzen  TEX  @MIN  Strikeouts       Over
# 34         890    Michael Lorenzen  TEX  @MIN  Strikeouts      Under
# 35         891    Michael Lorenzen  TEX  @MIN  Strikeouts      Under
# 36         920       Miles Mikolas  STL   CHC  Strikeouts       Over
# 37         921       Miles Mikolas  STL   CHC  Strikeouts      Under
# 38         926        Mitch Keller  PIT   ATL  Strikeouts       Over
# 39         927        Mitch Keller  PIT   ATL  Strikeouts      Under
# 40         952        Nick Pivetta  BOS   MIL  Strikeouts       Over
# 41         953        Nick Pivetta  BOS   MIL  Strikeouts      Under
# 42        1096  Spencer Arrighetti  HOU  @OAK  Strikeouts       Over
# 43        1097  Spencer Arrighetti  HOU  @OAK  Strikeouts      Under
# 44        1110        Tanner Bibee  CLE  @LAA  Strikeouts       Over
# 45        1111        Tanner Bibee  CLE  @LAA  Strikeouts      Under
# 46        1144     Trevor Williams  WSH   SEA  Strikeouts       Over
# 47        1145     Trevor Williams  WSH   SEA  Strikeouts      Under
# 48        1178      Walker Buehler  LAD  @CIN  Strikeouts       Over
