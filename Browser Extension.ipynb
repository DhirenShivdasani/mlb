# %%
import pandas as pd

# Load the CSV files
betting_odds_data = pd.read_csv('mlb_props.csv')
prizepicks_data = pd.read_csv('test2.csv')

# Display the data to understand its structure
betting_odds_data[betting_odds_data['team'] == 'BAL']
# Out:
#             PlayerName team  opp        Prop Over_Under draftkings  \
# 8      Adley Rutschman  BAL  BOS       bases       Over     (1.5)
# 9      Adley Rutschman  BAL  BOS       bases      Under     (1.5)
# 10     Adley Rutschman  BAL  BOS        runs       Over     (0.5)
# 11     Adley Rutschman  BAL  BOS        runs      Under     (0.5)
# 50   Anthony Santander  BAL  BOS       bases       Over     (1.5)
# 51   Anthony Santander  BAL  BOS       bases      Under     (1.5)
# 52   Anthony Santander  BAL  BOS        runs       Over     (0.5)
# 53   Anthony Santander  BAL  BOS        runs      Under     (0.5)
# 156     Cedric Mullins  BAL  BOS       bases       Over     (0.5)
# 157     Cedric Mullins  BAL  BOS       bases      Under     (0.5)
# 158     Cedric Mullins  BAL  BOS        runs       Over     (0.5)
# 159     Cedric Mullins  BAL  BOS        runs      Under     (0.5)
# 184         Cole Irvin  BAL  BOS  strikeouts       Over     (3.5)
# 185         Cole Irvin  BAL  BOS  strikeouts      Under     (3.5)
# 186      Colton Cowser  BAL  BOS       bases       Over     (1.5)
# 187      Colton Cowser  BAL  BOS       bases      Under     (1.5)
# 188      Colton Cowser  BAL  BOS        runs       Over     (0.5)
# 189      Colton Cowser  BAL  BOS        runs      Under     (0.5)
# 328   Gunnar Henderson  BAL  BOS       bases       Over     (1.5)
# 329   Gunnar Henderson  BAL  BOS       bases      Under     (1.5)
# 330   Gunnar Henderson  BAL  BOS        runs       Over     (0.5)
# 331   Gunnar Henderson  BAL  BOS        runs      Under     (0.5)
# 478    Jordan Westburg  BAL  BOS       bases       Over     (1.5)
# 479    Jordan Westburg  BAL  BOS       bases      Under     (1.5)
# 480    Jordan Westburg  BAL  BOS        runs       Over     (0.5)
# 481    Jordan Westburg  BAL  BOS        runs      Under     (0.5)
# 482        Jorge Mateo  BAL  BOS       bases       Over     (0.5)
# 483        Jorge Mateo  BAL  BOS       bases      Under     (0.5)
# 484        Jorge Mateo  BAL  BOS        runs       Over     (0.5)
# 485        Jorge Mateo  BAL  BOS        runs      Under     (0.5)
# 556       Kyle Stowers  BAL  BOS       bases       Over     (0.5)
# 557       Kyle Stowers  BAL  BOS       bases      Under     (0.5)
# 558       Kyle Stowers  BAL  BOS        runs       Over     (0.5)
# 559       Kyle Stowers  BAL  BOS        runs      Under     (0.5)
# 796   Ryan Mountcastle  BAL  BOS       bases       Over     (1.5)
# 797   Ryan Mountcastle  BAL  BOS       bases      Under     (1.5)
# 798   Ryan Mountcastle  BAL  BOS        runs       Over     (0.5)
# 799   Ryan Mountcastle  BAL  BOS        runs      Under     (0.5)
# 800       Ryan O'Hearn  BAL  BOS       bases       Over     (1.5)
# 801       Ryan O'Hearn  BAL  BOS       bases      Under     (1.5)
# 802       Ryan O'Hearn  BAL  BOS        runs       Over     (0.5)
# 803       Ryan O'Hearn  BAL  BOS        runs      Under     (0.5)
#
#         fanduel     mgm
# 8           NaN  (1.5)
# 9           NaN  (1.5)
# 10    (0.5) 220  (0.5)
# 11   (0.5) -300  (0.5)
# 50          NaN  (1.5)
# 51          NaN  (1.5)
# 52          NaN  (0.5)
# 53          NaN  (0.5)
# 156         NaN  (0.5)
# 157         NaN  (0.5)
# 158   (0.5) 220  (0.5)
# 159  (0.5) -290  (0.5)
# 184      (3.5)   (3.5)
# 185      (3.5)   (3.5)
# 186         NaN  (1.5)
# 187         NaN  (1.5)
# 188   (1.5) 150  (0.5)
# 189  (1.5) -195  (0.5)
# 328         NaN  (1.5)
# 329         NaN  (1.5)
# 330   (0.5) 185  (0.5)
# 331  (0.5) -240  (0.5)
# 478         NaN  (1.5)
# 479         NaN  (1.5)
# 480   (0.5) 175  (0.5)
# 481  (0.5) -240  (0.5)
# 482         NaN  (0.5)
# 483         NaN  (0.5)
# 484      (0.5)   (0.5)
# 485      (0.5)   (0.5)
# 556         NaN  (0.5)
# 557         NaN  (0.5)
# 558   (0.5) 260  (0.5)
# 559  (0.5) -350  (0.5)
# 796         NaN  (1.5)
# 797         NaN  (1.5)
# 798   (0.5) 130  (0.5)
# 799  (0.5) -165  (0.5)
# 800         NaN  (1.5)
# 801         NaN  (1.5)
# 802   (0.5) 260  (0.5)
# 803  (0.5) -370  (0.5)

# %%
prizepicks_data['Prop'].unique()
# Out:
# array(['Hitter Fantasy Score', 'Total Bases', '1st Inning Runs Allowed',
#        'Pitcher Strikeouts', 'Runs', 'Pitcher Fantasy Score',
#        'Pitcher Strikeouts (Combo)', 'Hits Allowed', 'Walks Allowed',
#        'Hits+Runs+RBIs', 'Singles', 'Pitching Outs', 'Walks', 'Hits',
#        'Earned Runs Allowed', 'Hitter Strikeouts'], dtype=object)

# %%
prizepicks_data = prizepicks_data[(prizepicks_data['Prop'] == 'Total Bases') | 
                                  (prizepicks_data['Prop'] == 'Pitcher Strikeouts') | 
                                  (prizepicks_data['Prop'] == 'Earned Runs Allowed')]

# %%
prizepicks_data
# Out:
#      Unnamed: 0              Name      Team  Value                 Prop
# 1             1    Jarred Kelenic  ATL - OF    0.5          Total Bases
# 4             4       Blake Snell    SF - P    6.0   Pitcher Strikeouts
# 8             8     Justin Steele   CHC - P    6.0   Pitcher Strikeouts
# 11           11     Justin Steele   CHC - P    6.0   Pitcher Strikeouts
# 12           12     Robert Gasser   MIL - P    4.0   Pitcher Strikeouts
# 13           13    Charlie Morton   ATL - P    6.0   Pitcher Strikeouts
# 14           14   Mitchell Parker   WSH - P    4.0   Pitcher Strikeouts
# 15           15     Xzavion Curry   CLE - P    3.0   Pitcher Strikeouts
# 16           16        Lance Lynn   STL - P    5.0   Pitcher Strikeouts
# 17           17       Blake Snell    SF - P    6.0   Pitcher Strikeouts
# 18           18    Taijuan Walker   PHI - P    4.0   Pitcher Strikeouts
# 19           19     Trevor Rogers   MIA - P    4.0   Pitcher Strikeouts
# 20           20      Michael King    SD - P    6.0   Pitcher Strikeouts
# 21           21    Framber Valdez   HOU - P    6.0   Pitcher Strikeouts
# 22           22      Miguel Amaya   CHC - C    0.5          Total Bases
# 23           23      Austin Riley  ATL - IF    1.5          Total Bases
# 24           24    Jarred Kelenic  ATL - OF    0.5          Total Bases
# 25           25     Marcell Ozuna  ATL - DH    1.5          Total Bases
# 26           26      Ozzie Albies  ATL - IF    1.5          Total Bases
# 27           27   Brendan Rodgers  COL - IF    1.5          Total Bases
# 28           28  Charlie Blackmon  COL - OF    1.5          Total Bases
# 29           29         David Fry  CLE - IF    1.5          Total Bases
# 30           30        Elias Díaz   COL - C    1.5          Total Bases
# 31           31    Kyle Schwarber  PHI - DH    0.5          Total Bases
# 32           32       Nick Fortes   MIA - C    0.5          Total Bases
# 33           33    Chas McCormick  HOU - OF    0.5          Total Bases
# 34           34     Jonatan Clase  SEA - OF    0.5          Total Bases
# 35           35    Yordan Alvarez  HOU - OF    1.5          Total Bases
# 36           36        Josh Rojas  SEA - IF    0.5          Total Bases
# 118         118    Taijuan Walker   PHI - P    2.5  Earned Runs Allowed
# 119         119      Bryce Miller   SEA - P    2.5  Earned Runs Allowed

# %%
prop_types= {
    'Pitcher Strikeouts': 'Strikeouts',
    'Earned Runs Allowed': 'Runs',
    'Total Bases': 'Total Bases'# example of making an indirect relationship
    # Add other mappings as required
}
prizepicks_data['Prop'] = prizepicks_data['Prop'].map(prop_types)

# %%
prizepicks_data
# Out:
#      Unnamed: 0              Name      Team  Value         Prop
# 1             1    Jarred Kelenic  ATL - OF    0.5  Total Bases
# 4             4       Blake Snell    SF - P    6.0   Strikeouts
# 8             8     Justin Steele   CHC - P    6.0   Strikeouts
# 11           11     Justin Steele   CHC - P    6.0   Strikeouts
# 12           12     Robert Gasser   MIL - P    4.0   Strikeouts
# 13           13    Charlie Morton   ATL - P    6.0   Strikeouts
# 14           14   Mitchell Parker   WSH - P    4.0   Strikeouts
# 15           15     Xzavion Curry   CLE - P    3.0   Strikeouts
# 16           16        Lance Lynn   STL - P    5.0   Strikeouts
# 17           17       Blake Snell    SF - P    6.0   Strikeouts
# 18           18    Taijuan Walker   PHI - P    4.0   Strikeouts
# 19           19     Trevor Rogers   MIA - P    4.0   Strikeouts
# 20           20      Michael King    SD - P    6.0   Strikeouts
# 21           21    Framber Valdez   HOU - P    6.0   Strikeouts
# 22           22      Miguel Amaya   CHC - C    0.5  Total Bases
# 23           23      Austin Riley  ATL - IF    1.5  Total Bases
# 24           24    Jarred Kelenic  ATL - OF    0.5  Total Bases
# 25           25     Marcell Ozuna  ATL - DH    1.5  Total Bases
# 26           26      Ozzie Albies  ATL - IF    1.5  Total Bases
# 27           27   Brendan Rodgers  COL - IF    1.5  Total Bases
# 28           28  Charlie Blackmon  COL - OF    1.5  Total Bases
# 29           29         David Fry  CLE - IF    1.5  Total Bases
# 30           30        Elias Díaz   COL - C    1.5  Total Bases
# 31           31    Kyle Schwarber  PHI - DH    0.5  Total Bases
# 32           32       Nick Fortes   MIA - C    0.5  Total Bases
# 33           33    Chas McCormick  HOU - OF    0.5  Total Bases
# 34           34     Jonatan Clase  SEA - OF    0.5  Total Bases
# 35           35    Yordan Alvarez  HOU - OF    1.5  Total Bases
# 36           36        Josh Rojas  SEA - IF    0.5  Total Bases
# 118         118    Taijuan Walker   PHI - P    2.5         Runs
# 119         119      Bryce Miller   SEA - P    2.5         Runs

# %%
prop_types= {
    'strikeouts': 'Strikeouts',
    'runs': 'Runs', 
    'bases': 'Total Bases'# example of making an indirect relationship
    # Add other mappings as required
}
betting_odds_data['Prop'] = betting_odds_data['Prop'].map(prop_types)

# %%
betting_odds_data['Prop'].unique()
# Out:
# array(['Total Bases', 'Runs', 'Strikeouts'], dtype=object)

# %%
prizepicks_data['Prop'].unique()
# Out:
# array(['Total Bases', 'Strikeouts', 'Runs'], dtype=object)

# %%
# Merging the datasets on player names and props
merged_data = pd.merge(betting_odds_data, prizepicks_data, left_on=['PlayerName', 'Prop'], right_on=['Name', 'Prop'], how='left')

# import ace_tools as tools; tools.display_dataframe_to_user(name="Merged Betting Data", dataframe=merged_data)

# Display the first few rows of the merged data
merged_data
# Out:
#          PlayerName team   opp         Prop Over_Under  draftkings fanduel  \
# 0       Adam Duvall  ATL   WSH  Total Bases       Over   (1.5) 100     NaN
# 1       Adam Duvall  ATL   WSH  Total Bases      Under  (1.5) -135     NaN
# 2       Adam Duvall  ATL   WSH         Runs       Over   (0.5) 105     NaN
# 3       Adam Duvall  ATL   WSH         Runs      Under  (0.5) -140     NaN
# 4      Adam Frazier   KC  @MIN  Total Bases       Over  (0.5) -155     NaN
# ..              ...  ...   ...          ...        ...         ...     ...
# 933     Yainer Diaz  HOU  @SEA         Runs      Under  (0.5) -230     NaN
# 934  Yordan Alvarez  HOU  @SEA  Total Bases       Over  (1.5) -105     NaN
# 935  Yordan Alvarez  HOU  @SEA  Total Bases      Under  (1.5) -125     NaN
# 936  Yordan Alvarez  HOU  @SEA         Runs       Over  (0.5) -105     NaN
# 937  Yordan Alvarez  HOU  @SEA         Runs      Under  (0.5) -125     NaN
#
#             mgm  Unnamed: 0            Name      Team  Value
# 0     (1.5) 100         NaN             NaN       NaN    NaN
# 1    (1.5) -135         NaN             NaN       NaN    NaN
# 2     (0.5) 105         NaN             NaN       NaN    NaN
# 3    (0.5) -140         NaN             NaN       NaN    NaN
# 4    (0.5) -155         NaN             NaN       NaN    NaN
# ..          ...         ...             ...       ...    ...
# 933  (0.5) -225         NaN             NaN       NaN    NaN
# 934  (1.5) -105        35.0  Yordan Alvarez  HOU - OF    1.5
# 935  (1.5) -120        35.0  Yordan Alvarez  HOU - OF    1.5
# 936  (0.5) -105         NaN             NaN       NaN    NaN
# 937  (0.5) -120         NaN             NaN       NaN    NaN
#
# [938 rows x 12 columns]

# %%
r = merged_data.drop(['Team', 'Name', 'Unnamed: 0'], axis =1)

# %%
r =r.dropna(subset=['Value'])

# %%
r = r.where(pd.notnull(r), "None")

# %%
r.isnull().sum()
# Out:
# PlayerName    0
# team          0
# opp           0
# Prop          0
# Over_Under    0
# draftkings    0
# fanduel       0
# mgm           0
# Value         0
# dtype: int64

# %%
r.to_csv('merged_data.csv')

# %%
df = pd.read_csv('merged_data.csv')

# %%
df
# Out:
#     Unnamed: 0        PlayerName team   opp         Prop Over_Under  \
# 0           56      Austin Riley  ATL   WSH  Total Bases       Over
# 1           57      Austin Riley  ATL   WSH  Total Bases      Under
# 2           64       Blake Snell   SF   PHI   Strikeouts       Over
# 3           65       Blake Snell   SF   PHI   Strikeouts       Over
# 4           66       Blake Snell   SF   PHI   Strikeouts      Under
# 5           67       Blake Snell   SF   PHI   Strikeouts      Under
# 6           92   Brendan Rodgers  COL   CLE  Total Bases       Over
# 7           93   Brendan Rodgers  COL   CLE  Total Bases      Under
# 8          162  Charlie Blackmon  COL   CLE  Total Bases       Over
# 9          163  Charlie Blackmon  COL   CLE  Total Bases      Under
# 10         166    Charlie Morton  ATL   WSH   Strikeouts       Over
# 11         167    Charlie Morton  ATL   WSH   Strikeouts      Under
# 12         168    Chas McCormick  HOU  @SEA  Total Bases       Over
# 13         169    Chas McCormick  HOU  @SEA  Total Bases      Under
# 14         230         David Fry  CLE  @COL  Total Bases       Over
# 15         231         David Fry  CLE  @COL  Total Bases      Under
# 16         294    Framber Valdez  HOU  @SEA   Strikeouts       Over
# 17         295    Framber Valdez  HOU  @SEA   Strikeouts      Under
# 18         414    Jarred Kelenic  ATL   WSH  Total Bases       Over
# 19         415    Jarred Kelenic  ATL   WSH  Total Bases       Over
# 20         416    Jarred Kelenic  ATL   WSH  Total Bases      Under
# 21         417    Jarred Kelenic  ATL   WSH  Total Bases      Under
# 22         474     Jonatan Clase  SEA   HOU  Total Bases       Over
# 23         475     Jonatan Clase  SEA   HOU  Total Bases      Under
# 24         514        Josh Rojas  SEA   HOU  Total Bases       Over
# 25         515        Josh Rojas  SEA   HOU  Total Bases      Under
# 26         526     Justin Steele  CHC  @MIL   Strikeouts       Over
# 27         527     Justin Steele  CHC  @MIL   Strikeouts       Over
# 28         528     Justin Steele  CHC  @MIL   Strikeouts      Under
# 29         529     Justin Steele  CHC  @MIL   Strikeouts      Under
# 30         558    Kyle Schwarber  PHI   @SF  Total Bases       Over
# 31         559    Kyle Schwarber  PHI   @SF  Total Bases      Under
# 32         574        Lance Lynn  STL  @CIN   Strikeouts       Over
# 33         575        Lance Lynn  STL  @CIN   Strikeouts      Under
# 34         612     Marcell Ozuna  ATL   WSH  Total Bases       Over
# 35         613     Marcell Ozuna  ATL   WSH  Total Bases      Under
# 36         648      Michael King   SD   MIA   Strikeouts       Over
# 37         649      Michael King   SD   MIA   Strikeouts      Under
# 38         650      Miguel Amaya  CHC  @MIL  Total Bases       Over
# 39         651      Miguel Amaya  CHC  @MIL  Total Bases      Under
# 40         682   Mitchell Parker  WSH  @ATL   Strikeouts       Over
# 41         683   Mitchell Parker  WSH  @ATL   Strikeouts      Under
# 42         696       Nick Fortes  MIA   @SD  Total Bases       Over
# 43         697       Nick Fortes  MIA   @SD  Total Bases      Under
# 44         752      Ozzie Albies  ATL   WSH  Total Bases       Over
# 45         753      Ozzie Albies  ATL   WSH  Total Bases      Under
# 46         788     Robert Gasser  MIL   CHC   Strikeouts       Over
# 47         789     Robert Gasser  MIL   CHC   Strikeouts      Under
# 48         838    Taijuan Walker  PHI   @SF   Strikeouts       Over
# 49         839    Taijuan Walker  PHI   @SF   Strikeouts      Under
# 50         860     Trevor Rogers  MIA   @SD   Strikeouts       Over
# 51         861     Trevor Rogers  MIA   @SD   Strikeouts      Under
# 52         928     Xzavion Curry  CLE  @COL   Strikeouts       Over
# 53         929     Xzavion Curry  CLE  @COL   Strikeouts      Under
# 54         934    Yordan Alvarez  HOU  @SEA  Total Bases       Over
# 55         935    Yordan Alvarez  HOU  @SEA  Total Bases      Under
#
#     draftkings     fanduel         mgm  Value
# 0   (1.5) -115         NaN  (1.5) -115    1.5
# 1   (1.5) -115         NaN  (1.5) -110    1.5
# 2    (6.5) 125   (6.5) 108   (6.5) 120    6.0
# 3    (6.5) 125   (6.5) 108   (6.5) 120    6.0
# 4   (6.5) -155  (6.5) -138  (6.5) -155    6.0
# 5   (6.5) -155  (6.5) -138  (6.5) -155    6.0
# 6   (1.5) -120         NaN  (1.5) -115    1.5
# 7   (1.5) -110         NaN  (1.5) -110    1.5
# 8   (1.5) -110         NaN  (1.5) -120    1.5
# 9   (1.5) -120         NaN  (1.5) -110    1.5
# 10  (5.5) -160  (5.5) -154  (5.5) -155    6.0
# 11   (5.5) 125   (5.5) 120   (5.5) 115    6.0
# 12  (0.5) -125         NaN  (0.5) -125    0.5
# 13  (0.5) -105         NaN  (0.5) -105    0.5
# 14  (1.5) -125         NaN  (1.5) -125    1.5
# 15  (1.5) -105         NaN  (1.5) -105    1.5
# 16  (5.5) -135  (5.5) -160  (5.5) -135    6.0
# 17   (5.5) 110   (5.5) 124   (5.5) 105    6.0
# 18  (0.5) -125         NaN  (0.5) -125    0.5
# 19  (0.5) -125         NaN  (0.5) -125    0.5
# 20  (0.5) -105         NaN  (0.5) -105    0.5
# 21  (0.5) -105         NaN  (0.5) -105    0.5
# 22  (0.5) -130         NaN  (0.5) -120    0.5
# 23  (0.5) -105         NaN  (0.5) -105    0.5
# 24  (0.5) -115         NaN  (0.5) -115    0.5
# 25  (0.5) -115         NaN  (0.5) -115    0.5
# 26  (5.5) -160  (5.5) -142  (5.5) -160    6.0
# 27  (5.5) -160  (5.5) -142  (5.5) -160    6.0
# 28   (5.5) 125   (5.5) 112   (5.5) 120    6.0
# 29   (5.5) 125   (5.5) 112   (5.5) 120    6.0
# 30  (0.5) -130         NaN  (0.5) -125    0.5
# 31  (0.5) -105         NaN  (0.5) -105    0.5
# 32   (5.5) 110   (5.5) 124   (5.5) 105    5.0
# 33  (5.5) -140  (5.5) -158  (5.5) -140    5.0
# 34  (1.5) -125         NaN  (1.5) -120    1.5
# 35  (1.5) -105         NaN  (1.5) -105    1.5
# 36  (5.5) -140  (5.5) -142  (5.5) -145    6.0
# 37   (5.5) 110   (5.5) 112   (5.5) 110    6.0
# 38  (0.5) -125         NaN  (0.5) -125    0.5
# 39  (0.5) -105         NaN  (0.5) -105    0.5
# 40   (4.5) 120   (4.5) 120   (4.5) 120    4.0
# 41  (4.5) -150  (4.5) -154  (4.5) -155    4.0
# 42  (0.5) -110         NaN  (0.5) -110    0.5
# 43  (0.5) -120         NaN  (0.5) -120    0.5
# 44  (1.5) -120         NaN  (1.5) -120    1.5
# 45  (1.5) -110         NaN  (1.5) -110    1.5
# 46  (3.5) -150  (3.5) -142  (3.5) -165    4.0
# 47   (3.5) 115   (3.5) 112   (3.5) 125    4.0
# 48  (3.5) -145  (3.5) -156  (3.5) -145    4.0
# 49   (3.5) 115   (3.5) 122   (3.5) 110    4.0
# 50  (3.5) -160  (3.5) -164  (3.5) -160    4.0
# 51   (3.5) 125   (3.5) 128   (3.5) 125    4.0
# 52  (2.5) -170  (2.5) -146  (2.5) -160    3.0
# 53   (2.5) 130   (2.5) 114   (2.5) 125    3.0
# 54  (1.5) -105         NaN  (1.5) -105    1.5
# 55  (1.5) -125         NaN  (1.5) -120    1.5
